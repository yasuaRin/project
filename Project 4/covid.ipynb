# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

df = pd.read_csv(r'C:\Users\dadia\Downloads\CoronaVirus Data.csv')
df.drop(columns=['Unnamed: 0', 'Month-Year'], inplace=True)

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
# ----> 6 df = pd.read_csv(r'C:\Users\dadia\Downloads\CoronaVirus Data.csv')
#       7 df.drop(columns=['Unnamed: 0', 'Month-Year'], inplace=True)
#       9 df
#
# ...

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df.shape
df.info()
#converting the date column into datetime format
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88230 entries, 0 to 93765
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Province/State   88230 non-null  object
#  1   Country/Region   88230 non-null  object
#  2   Lat              88230 non-null  float64
#  3   Long             88230 non-null  float64
#  4   Date             88230 non-null  datetime64[ns]
#  5   Confirmed        88230 non-null  int64
#  6   Deaths           88230 non-null  int64
#  7   Recovered        88230 non-null  float64
#  8   Confirmed Daily  88230 non-null  float64
#  9   Deaths Daily     88230 non-null  float64
#  10  Recovered Daily  88230 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(2)
# memory usage: 8.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 88230 entries, 0 to 93765
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ...

# %%
df.rename(columns={'Province/State': 'Province_State', 'Country/Region': 'Country_Region'}, inplace=True)
df
# Out:
#            Province_State      Country_Region        Lat        Long  \
# 0             Afghanistan         Afghanistan  33.939110   67.709953
# 1                 Albania             Albania  41.153300   20.168300
# 2                 Algeria             Algeria  28.033900    1.659600
# 3                 Andorra             Andorra  42.506300    1.521800
# 4                  Angola              Angola -11.202700   17.873900
# ...                   ...                 ...        ...         ...
# 93761             Vietnam             Vietnam  14.058324  108.277199
# 93762  West Bank and Gaza  West Bank and Gaza  31.952200   35.233200
# 93763               Yemen               Yemen  15.552727   48.516388
# 93764              Zambia              Zambia -13.133897   27.849332
# 93765            Zimbabwe            Zimbabwe -19.015438   29.154857
#
#             Date  Confirmed  Deaths  Recovered  Confirmed Daily  Deaths Daily  \
# ...

# %%
df.to_csv(r'C:\Users\dadia\Downloads\CoronaVirusNew.csv', index=False)

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

engine = create_engine('postgresql+psycopg2://postgres:admin@localhost:5432/covid_db')
connection = engine.connect()
#Extraction process
query = """
SELECT * FROM your_actual_table_name;  # Replace 'your_actual_table_name' with the correct table name
"""
df = pd.read_sql_query(query, con=connection)
df
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File c:\Users\dadia\.vscode\Python-Y2\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File c:\Users\dadia\.vscode\Python-Y2\.venv\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# UndefinedTable: relasi « province_state » tidak ada
# LINE 2: SELECT * FROM province_state;
#                       ^
#
#
# ...
